# %%
# .py 파일 수정사항 바로 반영하기 위한 옵션
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import genie_streaming_data_scraper as gs
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
import os
import json

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# # Data Scraping

# %%
url = 'https://xn--o39an51b2re.com/genie/chart/realtime/'
headers = {'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36'}

# %%
raw_data_path = '../data/raw/'     # raw data 저장할 위치

if not os.path.exists(raw_data_path):
    os.mkdir(raw_data_path)

# %%
data = gs.genie_datascraper(url, "2019-12-31 23", headers=headers)
# Out:
# 2020-01-01 00:00:00 시작
# 2020-02-01 00:00:00 시작
# 2020-02-08 00:00:00 아무노래_지코 (ZICO) 결측값 발생
# 2020-02-08 00:00:00 METEOR_창모 (CHANGMO) 결측값 발생
# 2020-02-08 00:00:00 Psycho_Red Velvet (레드벨벳) 결측값 발생
# 2020-02-08 00:00:00 Blueming_아이유 (IU) 결측값 발생
# 2020-02-08 00:00:00 또 사랑에 속다_에이트 (8eight) 결측값 발생
# 2020-02-08 00:00:00 늦은 밤 너의 집 앞 골목길에서_노을 결측값 발생
# 2020-02-08 00:00:00 다시 난, 여기_백예린 (Yerin Baek) 결측값 발생
# 2020-02-08 00:00:00 안녕_김재환 결측값 발생
# 2020-02-08 00:00:00 HIP_마마무(Mamamoo) 결측값 발생
# 2020-02-08 00:00:00 Birthday_Anne-Marie 결측값 발생
# 2020-02-08 00:00:00 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야_장범준 결측값 발생
# 2020-02-08 00:00:00 어떤 날엔_김재환 결측값 발생
# 2020-02-08 00:00:00 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지_AKMU (악뮤) 결측값 발생
# 2020-02-08 00:00:00 아마두 (Feat. 우원재 & 김효은 & 넉살 & Huckleberry P)_팔로알토 (Paloalto), The Quiett, 염따, 딥플로우, 사이먼 도미닉, 염따 & 딥플로우 & 팔로알토 (Paloalto) & The Quiett & 사이먼 도미닉 결측값 발생
# 2020-02-08 00:00:00 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)_마크툽 (Maktub) 결측값 발생
# 2020-02-08 00:00:00 Loveship_폴킴, 청하, 폴킴 & 청하 결측값 발생
# 2020-02-08 00:00:00 Love poem_아이유 (IU) 결측값 발생
# 2020-02-08 00:00:00 Square (2017)_백예린 (Yerin Baek) 결측값 발생
# 2020-02-08 00:00:00 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)_방탄소년단 결측값 발생
# 2020-02-08 00:00:00 먹구름_윤하 (YOUNHA) 결측값 발생
# 2020-02-08 00:00:00 Black Swan_방탄소년단 결측값 발생
# 2020-02-08 00:00:00 빌었어_창모 (CHANGMO) 결측값 발생
# 2020-02-08 00:00:00 사랑이란 멜로는 없어_전상근 결측값 발생
# 2020-02-08 00:00:00 Nerdy Love (Feat. 백예린)_pH-1 결측값 발생
# 2020-02-08 00:00:00 조금 취했어 (Prod. by 2soo)_임재현 결측값 발생
# 2020-02-08 00:00:00 이 노랜 꽤 오래된 거야 (A song from the past)_케이시 (Kassy), 솔라 (마마무), 솔라 (마마무) & 케이시 (Kassy) 결측값 발생
# 2020-02-08 00:00:00 나의 모든 날_김세정 결측값 발생
# 2020-02-08 00:00:00 교차로 (Crossroads)_여자친구 (GFRIEND) 결측값 발생
# 2020-02-08 00:00:00 안녕_폴킴 결측값 발생
# 2020-02-08 00:00:00 마음이 말하는 행복 (Happiness) (Feat.이라온)_마크툽 (Maktub) 결측값 발생
# 2020-02-08 00:00:00 다시 만날까 봐_V.O.S 결측값 발생
# 2020-02-08 00:00:00 다시는 사랑하지 않고, 이별에 아파하기 싫어_백지영 결측값 발생
# 2020-02-08 00:00:00 나의 오랜 연인에게_다비치 결측값 발생
# 2020-02-08 00:00:00 너를 사랑하고 있어_백현 (BAEKHYUN) 결측값 발생
# 2020-02-08 00:00:00 bad guy_Billie Eilish 결측값 발생
# 2020-02-08 00:00:00 2002_Anne-Marie 결측값 발생
# 2020-02-08 00:00:00 모든 날, 모든 순간 (Every day, Every Moment)_폴킴 결측값 발생
# 2020-02-08 00:00:00 ALL FOR YOU_젝스키스 결측값 발생
# 2020-02-08 00:00:00 봄날_방탄소년단 결측값 발생
# 2020-02-08 00:00:00 포장마차_황인욱 결측값 발생
# 2020-02-08 00:00:00 새 사랑_송하예 결측값 발생
# 2020-02-08 00:00:00 시든 꽃에 물을 주듯_HYNN (박혜원) 결측값 발생
# 2020-02-08 00:00:00 가라고 (Gotta Go)_선미 결측값 발생
# 2020-02-08 00:00:00 Memories_Maroon 5 결측값 발생
# 2020-02-08 00:00:00 Into the Unknown_Idina Menzel, AURORA, Idina Menzel & AURORA 결측값 발생
# 2020-02-08 00:00:00 헤어진 우리가 지켜야 할 것들_김나영, 양다일, 김나영 & 양다일 결측값 발생
# 2020-02-08 00:00:00 사랑에 연습이 있었다면 (Prod. by 2soo)_임재현 결측값 발생
# 2020-02-08 00:00:00 Comethru_Jeremy Zucker 결측값 발생
# 2020-02-08 00:00:00 내게 들려주고 싶은 말 (Dear Me)_태연 (TAEYEON) 결측값 발생
# 2020-02-08 00:00:00 사랑이 식었다고 말해도 돼_먼데이 키즈 (Monday Kiz) 결측값 발생
# 2020-02-08 00:00:00 있어줘요_장덕철 결측값 발생
# 2020-02-08 00:00:00 뛰어들게 (Dive)_iKON 결측값 발생
# 2020-02-08 00:00:00 Senorita_Shawn Mendes, Camila Cabello & Shawn Mendes, Camila Cabello 결측값 발생
# 2020-02-08 00:00:00 Paris in the Rain_Lauv 결측값 발생
# 2020-02-08 00:00:00 너를 만나_폴킴 결측값 발생
# 2020-02-08 00:00:00 시간의 바깥_아이유 (IU) 결측값 발생
# 2020-02-08 00:00:00 BAND_창모 (CHANGMO), 김효은, Hash Swan, ASH ISLAND, 창모 & Hash Swan & ASH ISLAND & 김효은 결측값 발생
# 2020-02-08 00:00:00 니 소식_송하예 결측값 발생
# 2020-02-08 00:00:00 인기 (Feat. 송가인 & 챈슬러)_MC몽 결측값 발생
# 2020-02-08 00:00:00 소우주 (Mikrokosmos)_방탄소년단 결측값 발생
# 2020-02-08 00:00:00 기억해줘요 내 모든 날과 그때를_거미 (Gummy) 결측값 발생
# 2020-02-08 00:00:00 이별주_황인욱 결측값 발생
# 2020-02-08 00:00:00 우는 법을 잊어버렸나요_이해리 (다비치) 결측값 발생
# 2020-02-08 00:00:00 불티 (Spark)_태연 (TAEYEON) 결측값 발생
# 2020-02-08 00:00:00 Flower_윤미래 결측값 발생
# 2020-02-08 00:00:00 IDOL_방탄소년단 결측값 발생
# 2020-02-08 00:00:00 그대라는 시_태연 (TAEYEON) 결측값 발생
# 2020-02-08 00:00:00 On My Way_Sabrina Carpenter, Farruko, Alan Walker, Alan Walker & Sabrina Carpenter & Farruko 결측값 발생
# 2020-02-08 00:00:00 우리 왜 헤어져야 해_신예영 결측값 발생
# 2020-02-08 00:00:00 이 번호로 전화해줘_바이브 결측값 발생
# 2020-02-08 00:00:00 Feel Special_TWICE (트와이스) 결측값 발생
# 2020-02-08 00:00:00 술이 문제야_장혜진, 윤민수(바이브), 장혜진 & 윤민수(바이브) 결측값 발생
# 2020-02-08 00:00:00 All Falls Down (Feat. Juliander)_Digital Farm Animals, Alan Walker, Noah Cyrus, Alan Walker & Noah Cyrus & Digital Farm Animals 결측값 발생
# 2020-02-08 00:00:00 Know Me Too Well_Danna Paola, New Hope Club, New Hope Club & Danna Paola 결측값 발생
# 2020-02-08 00:00:00 사계 (Four Seasons)_태연 (TAEYEON) 결측값 발생
# 2020-02-08 00:00:00 워커홀릭_볼빨간사춘기 결측값 발생
# 2020-02-08 00:00:00 노래방에서_장범준 결측값 발생
# 2020-02-08 00:00:00 꿈속에 너 (Feat. 전상근)_에이치코드 (H:CODE) 결측값 발생
# 2020-02-08 00:00:00 내 마음의 사진_송가인 결측값 발생
# 2020-02-08 00:00:00 주저하는 연인들을 위해_잔나비 결측값 발생
# 2020-02-08 00:00:00 십이월 이십오일의 고백_정승환 결측값 발생
# 2020-02-08 00:00:00 LION_(여자)아이들 결측값 발생
# 2020-02-08 00:00:00 그때의 우리_펀치 (Punch) 결측값 발생
# 2020-02-08 00:00:00 Make It Right_방탄소년단 결측값 발생
# 2020-02-08 00:00:00 가을밤 떠난 너_케이시 (Kassy) 결측값 발생
# 2020-02-08 00:00:00 Yummy_Justin Bieber 결측값 발생
# 2020-02-08 00:00:00 잘 살고 있다_V.O.S 결측값 발생
# 2020-02-08 00:00:00 너에게 못했던 내 마지막 말은_다비치 결측값 발생
# 2020-02-08 00:00:00 허전해_폴킴 결측값 발생
# 2020-02-08 00:00:00 그때가 좋았어_케이시 (Kassy) 결측값 발생
# 2020-02-08 00:00:00 너의 하루는 좀 어때_거미 (Gummy) 결측값 발생
# 2020-02-08 00:00:00 ROXANNE_Arizona Zervas 결측값 발생
# 2020-02-08 00:00:00 노을_다비치 결측값 발생
# 2020-02-08 00:00:00 Dionysus_방탄소년단 결측값 발생
# 2020-02-08 00:00:00 벗_닐로 (Nilo) 결측값 발생
# 2020-02-08 00:00:00 차가워진 이 바람엔 우리가 써있어 (Bad Love)_HYNN (박혜원) 결측값 발생
# 2020-02-08 00:00:00 Way Back Home_숀 (SHAUN) 결측값 발생
# 2020-02-08 00:00:00 헤어지자 (Prod. by 정키 (Jung Key))_휘인 (Whee In) 결측값 발생
# 2020-02-08 00:00:00 Obsession_EXO 결측값 발생
# 2020-02-08 00:00:00 나의 어깨에 기대어요_10CM 결측값 발생
# 2020-02-08 01:00:00 아무노래_지코 (ZICO) 결측값 발생
# 2020-02-08 01:00:00 METEOR_창모 (CHANGMO) 결측값 발생
# 2020-02-08 01:00:00 Psycho_Red Velvet (레드벨벳) 결측값 발생
# 2020-02-08 01:00:00 또 사랑에 속다_에이트 (8eight) 결측값 발생
# 2020-02-08 01:00:00 안녕_김재환 결측값 발생
# 2020-02-08 01:00:00 Blueming_아이유 (IU) 결측값 발생
# 2020-02-08 01:00:00 다시 난, 여기_백예린 (Yerin Baek) 결측값 발생
# 2020-02-08 01:00:00 늦은 밤 너의 집 앞 골목길에서_노을 결측값 발생
# 2020-02-08 01:00:00 HIP_마마무(Mamamoo) 결측값 발생
# 2020-02-08 01:00:00 Birthday_Anne-Marie 결측값 발생
# 2020-02-08 01:00:00 어떤 날엔_김재환 결측값 발생
# 2020-02-08 01:00:00 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지_AKMU (악뮤) 결측값 발생
# 2020-02-08 01:00:00 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야_장범준 결측값 발생
# 2020-02-08 01:00:00 Love poem_아이유 (IU) 결측값 발생
# 2020-02-08 01:00:00 아마두 (Feat. 우원재 & 김효은 & 넉살 & Huckleberry P)_팔로알토 (Paloalto), The Quiett, 염따, 딥플로우, 사이먼 도미닉, 염따 & 딥플로우 & 팔로알토 (Paloalto) & The Quiett & 사이먼 도미닉 결측값 발생
# 2020-02-08 01:00:00 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)_마크툽 (Maktub) 결측값 발생
# 2020-02-08 01:00:00 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)_방탄소년단 결측값 발생
# 2020-02-08 01:00:00 Square (2017)_백예린 (Yerin Baek) 결측값 발생
# 2020-02-08 01:00:00 Black Swan_방탄소년단 결측값 발생
# 2020-02-08 01:00:00 먹구름_윤하 (YOUNHA) 결측값 발생
# 2020-02-08 01:00:00 빌었어_창모 (CHANGMO) 결측값 발생
# 2020-02-08 01:00:00 사랑이란 멜로는 없어_전상근 결측값 발생
# 2020-02-08 01:00:00 교차로 (Crossroads)_여자친구 (GFRIEND) 결측값 발생
# 2020-02-08 01:00:00 모든 날, 모든 순간 (Every day, Every Moment)_폴킴 결측값 발생
# 2020-02-08 01:00:00 마음이 말하는 행복 (Happiness) (Feat.이라온)_마크툽 (Maktub) 결측값 발생
# 2020-02-08 01:00:00 Loveship_폴킴, 청하, 폴킴 & 청하 결측값 발생
# 2020-02-08 01:00:00 조금 취했어 (Prod. by 2soo)_임재현 결측값 발생
# 2020-02-08 01:00:00 나의 모든 날_김세정 결측값 발생
# 2020-02-08 01:00:00 너를 사랑하고 있어_백현 (BAEKHYUN) 결측값 발생
# 2020-02-08 01:00:00 안녕_폴킴 결측값 발생
# 2020-02-08 01:00:00 이 노랜 꽤 오래된 거야 (A song from the past)_케이시 (Kassy), 솔라 (마마무), 솔라 (마마무) & 케이시 (Kassy) 결측값 발생
# 2020-02-08 01:00:00 다시는 사랑하지 않고, 이별에 아파하기 싫어_백지영 결측값 발생
# 2020-02-08 01:00:00 ALL FOR YOU_젝스키스 결측값 발생
# 2020-02-08 01:00:00 내게 들려주고 싶은 말 (Dear Me)_태연 (TAEYEON) 결측값 발생
# 2020-02-08 01:00:00 다시 만날까 봐_V.O.S 결측값 발생
# 2020-02-08 01:00:00 봄날_방탄소년단 결측값 발생
# 2020-02-08 01:00:00 Nerdy Love (Feat. 백예린)_pH-1 결측값 발생
# 2020-02-08 01:00:00 나의 오랜 연인에게_다비치 결측값 발생
# 2020-02-08 01:00:00 2002_Anne-Marie 결측값 발생
# 2020-02-08 01:00:00 포장마차_황인욱 결측값 발생
# 2020-02-08 01:00:00 시든 꽃에 물을 주듯_HYNN (박혜원) 결측값 발생
# 2020-02-08 01:00:00 Flower_윤미래 결측값 발생
# 2020-02-08 01:00:00 bad guy_Billie Eilish 결측값 발생
# 2020-02-08 01:00:00 헤어진 우리가 지켜야 할 것들_김나영, 양다일, 김나영 & 양다일 결측값 발생
# 2020-02-08 01:00:00 Memories_Maroon 5 결측값 발생
# 2020-02-08 01:00:00 사랑에 연습이 있었다면 (Prod. by 2soo)_임재현 결측값 발생
# 2020-02-08 01:00:00 새 사랑_송하예 결측값 발생
# 2020-02-08 01:00:00 사랑이 식었다고 말해도 돼_먼데이 키즈 (Monday Kiz) 결측값 발생
# 2020-02-08 01:00:00 가라고 (Gotta Go)_선미 결측값 발생
# 2020-02-08 01:00:00 니 소식_송하예 결측값 발생
# 2020-02-08 01:00:00 있어줘요_장덕철 결측값 발생
# 2020-02-08 01:00:00 소우주 (Mikrokosmos)_방탄소년단 결측값 발생
# 2020-02-08 01:00:00 Comethru_Jeremy Zucker 결측값 발생
# 2020-02-08 01:00:00 Into the Unknown_Idina Menzel, AURORA, Idina Menzel & AURORA 결측값 발생
# 2020-02-08 01:00:00 뛰어들게 (Dive)_iKON 결측값 발생
# 2020-02-08 01:00:00 그때가 좋았어_케이시 (Kassy) 결측값 발생
# 2020-02-08 01:00:00 Senorita_Shawn Mendes, Camila Cabello & Shawn Mendes, Camila Cabello 결측값 발생
# 2020-02-08 01:00:00 헤어지자 (Prod. by 정키 (Jung Key))_휘인 (Whee In) 결측값 발생
# 2020-02-08 01:00:00 BAND_창모 (CHANGMO), 김효은, Hash Swan, ASH ISLAND, 창모 & Hash Swan & ASH ISLAND & 김효은 결측값 발생
# 2020-02-08 01:00:00 너를 만나_폴킴 결측값 발생
# 2020-02-08 01:00:00 IDOL_방탄소년단 결측값 발생
# 2020-02-08 01:00:00 Paris in the Rain_Lauv 결측값 발생
# 2020-02-08 01:00:00 너에게 못했던 내 마지막 말은_다비치 결측값 발생
# 2020-02-08 01:00:00 우는 법을 잊어버렸나요_이해리 (다비치) 결측값 발생
# 2020-02-08 01:00:00 이별주_황인욱 결측값 발생
# 2020-02-08 01:00:00 우리 왜 헤어져야 해_신예영 결측값 발생
# 2020-02-08 01:00:00 이 번호로 전화해줘_바이브 결측값 발생
# 2020-02-08 01:00:00 불티 (Spark)_태연 (TAEYEON) 결측값 발생
# 2020-02-08 01:00:00 기억해줘요 내 모든 날과 그때를_거미 (Gummy) 결측값 발생
# 2020-02-08 01:00:00 시간의 바깥_아이유 (IU) 결측값 발생
# 2020-02-08 01:00:00 인기 (Feat. 송가인 & 챈슬러)_MC몽 결측값 발생
# 2020-02-08 01:00:00 십이월 이십오일의 고백_정승환 결측값 발생
# 2020-02-08 01:00:00 주저하는 연인들을 위해_잔나비 결측값 발생
# 2020-02-08 01:00:00 노래방에서_장범준 결측값 발생
# 2020-02-08 01:00:00 Make It Right_방탄소년단 결측값 발생
# 2020-02-08 01:00:00 내 마음의 사진_송가인 결측값 발생
# 2020-02-08 01:00:00 그대라는 시_태연 (TAEYEON) 결측값 발생
# 2020-02-08 01:00:00 잘 살고 있다_V.O.S 결측값 발생
# 2020-02-08 01:00:00 술이 문제야_장혜진, 윤민수(바이브), 장혜진 & 윤민수(바이브) 결측값 발생
# 2020-02-08 01:00:00 꿈속에 너 (Feat. 전상근)_에이치코드 (H:CODE) 결측값 발생
# 2020-02-08 01:00:00 Feel Special_TWICE (트와이스) 결측값 발생
# 2020-02-08 01:00:00 돌덩이_하현우 (국카스텐) 결측값 발생
# 2020-02-08 01:00:00 LION_(여자)아이들 결측값 발생
# 2020-02-08 01:00:00 워커홀릭_볼빨간사춘기 결측값 발생
# 2020-02-08 01:00:00 허전해_폴킴 결측값 발생
# 2020-02-08 01:00:00 가을밤 떠난 너_케이시 (Kassy) 결측값 발생
# 2020-02-08 01:00:00 Know Me Too Well_Danna Paola, New Hope Club, New Hope Club & Danna Paola 결측값 발생
# 2020-02-08 01:00:00 차가워진 이 바람엔 우리가 써있어 (Bad Love)_HYNN (박혜원) 결측값 발생
# 2020-02-08 01:00:00 All Falls Down (Feat. Juliander)_Digital Farm Animals, Alan Walker, Noah Cyrus, Alan Walker & Noah Cyrus & Digital Farm Animals 결측값 발생
# 2020-02-08 01:00:00 그때의 우리_펀치 (Punch) 결측값 발생
# 2020-02-08 01:00:00 Dionysus_방탄소년단 결측값 발생
# 2020-02-08 01:00:00 On My Way_Sabrina Carpenter, Farruko, Alan Walker, Alan Walker & Sabrina Carpenter & Farruko 결측값 발생
# 2020-02-08 01:00:00 Obsession_EXO 결측값 발생
# 2020-02-08 01:00:00 노을_다비치 결측값 발생
# 2020-02-08 01:00:00 나만 아픈 일_이해리 (다비치) 결측값 발생
# 2020-02-08 01:00:00 사계 (Four Seasons)_태연 (TAEYEON) 결측값 발생
# 2020-02-08 01:00:00 우연인 듯 운명_10CM 결측값 발생
# 2020-02-08 01:00:00 하루에도 열두 번_윤건 결측값 발생
# 2020-02-08 01:00:00 ROXANNE_Arizona Zervas 결측값 발생
# 2020-02-08 01:00:00 Yummy_Justin Bieber 결측값 발생
# --------------------------------------------------
# 2020-02-08 02:00:00에 해당하는 페이지에는 음원 정보가 없음
# --------------------------------------------------
# --------------------------------------------------
# 2020-02-08 03:00:00에 해당하는 페이지에는 음원 정보가 없음
# --------------------------------------------------
# --------------------------------------------------
# 2020-02-08 04:00:00에 해당하는 페이지에는 음원 정보가 없음
# --------------------------------------------------
# --------------------------------------------------
# 2020-02-08 05:00:00에 해당하는 페이지에는 음원 정보가 없음
# --------------------------------------------------
# --------------------------------------------------
# 2020-02-08 06:00:00에 해당하는 페이지에는 음원 정보가 없음
# --------------------------------------------------
# 2020-02-08 07:00:00 아무노래_지코 (ZICO) 결측값 발생
# 2020-02-08 07:00:00 METEOR_창모 (CHANGMO) 결측값 발생
# 2020-02-08 07:00:00 안녕_김재환 결측값 발생
# 2020-02-08 07:00:00 ALL FOR YOU_젝스키스 결측값 발생
# 2020-02-08 07:00:00 Psycho_Red Velvet (레드벨벳) 결측값 발생
# 2020-02-08 07:00:00 또 사랑에 속다_에이트 (8eight) 결측값 발생
# 2020-02-08 07:00:00 늦은 밤 너의 집 앞 골목길에서_노을 결측값 발생
# 2020-02-08 07:00:00 Blueming_아이유 (IU) 결측값 발생
# 2020-02-08 07:00:00 다시 난, 여기_백예린 (Yerin Baek) 결측값 발생
# 2020-02-08 07:00:00 어떤 날엔_김재환 결측값 발생
# 2020-02-08 07:00:00 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)_방탄소년단 결측값 발생
# 2020-02-08 07:00:00 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야_장범준 결측값 발생
# 2020-02-08 07:00:00 HIP_마마무(Mamamoo) 결측값 발생
# 2020-02-08 07:00:00 Black Swan_방탄소년단 결측값 발생
# 2020-02-08 07:00:00 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지_AKMU (악뮤) 결측값 발생
# 2020-02-08 07:00:00 Love poem_아이유 (IU) 결측값 발생
# 2020-02-08 07:00:00 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)_마크툽 (Maktub) 결측값 발생
# 2020-02-08 07:00:00 아마두 (Feat. 우원재 & 김효은 & 넉살 & Huckleberry P)_팔로알토 (Paloalto), The Quiett, 염따, 딥플로우, 사이먼 도미닉, 염따 & 딥플로우 & 팔로알토 (Paloalto) & The Quiett & 사이먼 도미닉 결측값 발생
# 2020-02-08 07:00:00 봄날_방탄소년단 결측값 발생
# 2020-02-08 07:00:00 조금 취했어 (Prod. by 2soo)_임재현 결측값 발생
# 2020-02-08 07:00:00 Square (2017)_백예린 (Yerin Baek) 결측값 발생
# 2020-02-08 07:00:00 먹구름_윤하 (YOUNHA) 결측값 발생
# 2020-02-08 07:00:00 사랑이란 멜로는 없어_전상근 결측값 발생
# 2020-02-08 07:00:00 안녕_폴킴 결측값 발생
# 2020-02-08 07:00:00 너를 사랑하고 있어_백현 (BAEKHYUN) 결측값 발생
# 2020-02-08 07:00:00 빌었어_창모 (CHANGMO) 결측값 발생
# 2020-02-08 07:00:00 소우주 (Mikrokosmos)_방탄소년단 결측값 발생
# 2020-02-08 07:00:00 포장마차_황인욱 결측값 발생
# 2020-02-08 07:00:00 모든 날, 모든 순간 (Every day, Every Moment)_폴킴 결측값 발생
# 2020-02-08 07:00:00 IDOL_방탄소년단 결측값 발생
# 2020-02-08 07:00:00 마음이 말하는 행복 (Happiness) (Feat.이라온)_마크툽 (Maktub) 결측값 발생
# 2020-02-08 07:00:00 교차로 (Crossroads)_여자친구 (GFRIEND) 결측값 발생
# 2020-02-08 07:00:00 이 노랜 꽤 오래된 거야 (A song from the past)_케이시 (Kassy), 솔라 (마마무), 솔라 (마마무) & 케이시 (Kassy) 결측값 발생
# 2020-02-08 07:00:00 2002_Anne-Marie 결측값 발생
# 2020-02-08 07:00:00 다시는 사랑하지 않고, 이별에 아파하기 싫어_백지영 결측값 발생
# 2020-02-08 07:00:00 다시 만날까 봐_V.O.S 결측값 발생
# 2020-02-08 07:00:00 나의 모든 날_김세정 결측값 발생
# 2020-02-08 07:00:00 있어줘요_장덕철 결측값 발생
# 2020-02-08 07:00:00 새 사랑_송하예 결측값 발생
# 2020-02-08 07:00:00 Make It Right_방탄소년단 결측값 발생
# 2020-02-08 07:00:00 Loveship_폴킴, 청하, 폴킴 & 청하 결측값 발생
# 2020-02-08 07:00:00 Dionysus_방탄소년단 결측값 발생
# 2020-02-08 07:00:00 사랑에 연습이 있었다면 (Prod. by 2soo)_임재현 결측값 발생
# 2020-02-08 07:00:00 Birthday_Anne-Marie 결측값 발생
# 2020-02-08 07:00:00 헤어진 우리가 지켜야 할 것들_김나영, 양다일, 김나영 & 양다일 결측값 발생
# 2020-02-08 07:00:00 시든 꽃에 물을 주듯_HYNN (박혜원) 결측값 발생
# 2020-02-08 07:00:00 사랑이 식었다고 말해도 돼_먼데이 키즈 (Monday Kiz) 결측값 발생
# 2020-02-08 07:00:00 이별주_황인욱 결측값 발생
# 2020-02-08 07:00:00 bad guy_Billie Eilish 결측값 발생
# 2020-02-08 07:00:00 나의 오랜 연인에게_다비치 결측값 발생
# 2020-02-08 07:00:00 니 소식_송하예 결측값 발생
# 2020-02-08 07:00:00 이 번호로 전화해줘_바이브 결측값 발생
# 2020-02-08 07:00:00 Senorita_Shawn Mendes, Camila Cabello & Shawn Mendes, Camila Cabello 결측값 발생
# 2020-02-08 07:00:00 Nerdy Love (Feat. 백예린)_pH-1 결측값 발생
# 2020-02-08 07:00:00 내게 들려주고 싶은 말 (Dear Me)_태연 (TAEYEON) 결측값 발생
# 2020-02-08 07:00:00 너를 만나_폴킴 결측값 발생
# 2020-02-08 07:00:00 우리 왜 헤어져야 해_신예영 결측값 발생
# 2020-02-08 07:00:00 술이 문제야_장혜진, 윤민수(바이브), 장혜진 & 윤민수(바이브) 결측값 발생
# 2020-02-08 07:00:00 Obsession_EXO 결측값 발생
# 2020-02-08 07:00:00 Into the Unknown_Idina Menzel, AURORA, Idina Menzel & AURORA 결측값 발생
# 2020-02-08 07:00:00 잘 살고 있다_V.O.S 결측값 발생
# 2020-02-08 07:00:00 인기 (Feat. 송가인 & 챈슬러)_MC몽 결측값 발생
# 2020-02-08 07:00:00 워커홀릭_볼빨간사춘기 결측값 발생
# 2020-02-08 07:00:00 우는 법을 잊어버렸나요_이해리 (다비치) 결측값 발생
# 2020-02-08 07:00:00 헤어지자 (Prod. by 정키 (Jung Key))_휘인 (Whee In) 결측값 발생
# 2020-02-08 07:00:00 기억해줘요 내 모든 날과 그때를_거미 (Gummy) 결측값 발생
# 2020-02-08 07:00:00 그대라는 시_태연 (TAEYEON) 결측값 발생
# 2020-02-08 07:00:00 차가워진 이 바람엔 우리가 써있어 (Bad Love)_HYNN (박혜원) 결측값 발생
# 2020-02-08 07:00:00 십이월 이십오일의 고백_정승환 결측값 발생
# 2020-02-08 07:00:00 BAND_창모 (CHANGMO), 김효은, Hash Swan, ASH ISLAND, 창모 & Hash Swan & ASH ISLAND & 김효은 결측값 발생
# 2020-02-08 07:00:00 Comethru_Jeremy Zucker 결측값 발생
# 2020-02-08 07:00:00 불티 (Spark)_태연 (TAEYEON) 결측값 발생
# 2020-02-08 07:00:00 안녕하세요_김재환 결측값 발생
# 2020-02-08 07:00:00 꿈속에 너 (Feat. 전상근)_에이치코드 (H:CODE) 결측값 발생
# 2020-02-08 07:00:00 너에게 못했던 내 마지막 말은_다비치 결측값 발생
# 2020-02-08 07:00:00 그때가 좋았어_케이시 (Kassy) 결측값 발생
# 2020-02-08 07:00:00 내 마음의 사진_송가인 결측값 발생
# 2020-02-08 07:00:00 Memories_Maroon 5 결측값 발생
# 2020-02-08 07:00:00 뛰어들게 (Dive)_iKON 결측값 발생
# 2020-02-08 07:00:00 벗_닐로 (Nilo) 결측값 발생
# 2020-02-08 07:00:00 Flower_윤미래 결측값 발생
# 2020-02-08 07:00:00 미안해_양다일 결측값 발생
# 2020-02-08 07:00:00 가을밤 떠난 너_케이시 (Kassy) 결측값 발생
# 2020-02-08 07:00:00 노래방에서_장범준 결측값 발생
# 2020-02-08 07:00:00 나의 어깨에 기대어요_10CM 결측값 발생
# 2020-02-08 07:00:00 Paris in the Rain_Lauv 결측값 발생
# 2020-02-08 07:00:00 솔직하게 말해서 나_김나영 결측값 발생
# 2020-02-08 07:00:00 그때의 우리_펀치 (Punch) 결측값 발생
# 2020-02-08 07:00:00 주저하는 연인들을 위해_잔나비 결측값 발생
# 2020-02-08 07:00:00 하루에도 열두 번_윤건 결측값 발생
# 2020-02-08 07:00:00 밤편지_아이유 (IU) 결측값 발생
# 2020-02-08 07:00:00 시간의 바깥_아이유 (IU) 결측값 발생
# 2020-02-08 07:00:00 헤어져줘서 고마워_벤 결측값 발생
# 2020-02-08 07:00:00 가라고 (Gotta Go)_선미 결측값 발생
# 2020-02-08 07:00:00 사계 (Four Seasons)_태연 (TAEYEON) 결측값 발생
# 2020-02-08 07:00:00 Way Back Home_숀 (SHAUN) 결측값 발생
# 2020-02-08 07:00:00 Feel Special_TWICE (트와이스) 결측값 발생
# 2020-02-08 07:00:00 시간이 필요해_김재환 결측값 발생
# 2020-02-08 07:00:00 노을_다비치 결측값 발생
# 2020-02-08 07:00:00 Go away go away_찬열 (CHANYEOL), 펀치 (Punch), 찬열 (CHANYEOL) & 펀치 (Punch) 결측값 발생
# 2020-02-08 08:00:00 아무노래_지코 (ZICO) 결측값 발생
# 2020-02-08 08:00:00 METEOR_창모 (CHANGMO) 결측값 발생
# 2020-02-08 08:00:00 안녕_김재환 결측값 발생
# 2020-02-08 08:00:00 ALL FOR YOU_젝스키스 결측값 발생
# 2020-02-08 08:00:00 또 사랑에 속다_에이트 (8eight) 결측값 발생
# 2020-02-08 08:00:00 Psycho_Red Velvet (레드벨벳) 결측값 발생
# 2020-02-08 08:00:00 늦은 밤 너의 집 앞 골목길에서_노을 결측값 발생
# 2020-02-08 08:00:00 Blueming_아이유 (IU) 결측값 발생
# 2020-02-08 08:00:00 다시 난, 여기_백예린 (Yerin Baek) 결측값 발생
# 2020-02-08 08:00:00 어떤 날엔_김재환 결측값 발생
# 2020-02-08 08:00:00 HIP_마마무(Mamamoo) 결측값 발생
# 2020-02-08 08:00:00 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야_장범준 결측값 발생
# 2020-02-08 08:00:00 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)_방탄소년단 결측값 발생
# 2020-02-08 08:00:00 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지_AKMU (악뮤) 결측값 발생
# 2020-02-08 08:00:00 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)_마크툽 (Maktub) 결측값 발생
# 2020-02-08 08:00:00 Black Swan_방탄소년단 결측값 발생
# 2020-02-08 08:00:00 아마두 (Feat. 우원재 & 김효은 & 넉살 & Huckleberry P)_팔로알토 (Paloalto), The Quiett, 염따, 딥플로우, 사이먼 도미닉, 염따 & 딥플로우 & 팔로알토 (Paloalto) & The Quiett & 사이먼 도미닉 결측값 발생
# 2020-02-08 08:00:00 Love poem_아이유 (IU) 결측값 발생
# 2020-02-08 08:00:00 먹구름_윤하 (YOUNHA) 결측값 발생
# 2020-02-08 08:00:00 빌었어_창모 (CHANGMO) 결측값 발생
# 2020-02-08 08:00:00 Loveship_폴킴, 청하, 폴킴 & 청하 결측값 발생
# 2020-02-08 08:00:00 조금 취했어 (Prod. by 2soo)_임재현 결측값 발생
# 2020-02-08 08:00:00 안녕_폴킴 결측값 발생
# 2020-02-08 08:00:00 사랑이란 멜로는 없어_전상근 결측값 발생
# 2020-02-08 08:00:00 Square (2017)_백예린 (Yerin Baek) 결측값 발생
# 2020-02-08 08:00:00 봄날_방탄소년단 결측값 발생
# 2020-02-08 08:00:00 다시는 사랑하지 않고, 이별에 아파하기 싫어_백지영 결측값 발생
# 2020-02-08 08:00:00 이 노랜 꽤 오래된 거야 (A song from the past)_케이시 (Kassy), 솔라 (마마무), 솔라 (마마무) & 케이시 (Kassy) 결측값 발생
# 2020-02-08 08:00:00 너를 사랑하고 있어_백현 (BAEKHYUN) 결측값 발생
# 2020-02-08 08:00:00 마음이 말하는 행복 (Happiness) (Feat.이라온)_마크툽 (Maktub) 결측값 발생
# 2020-02-08 08:00:00 모든 날, 모든 순간 (Every day, Every Moment)_폴킴 결측값 발생
# 2020-02-08 08:00:00 다시 만날까 봐_V.O.S 결측값 발생
# 2020-02-08 08:00:00 교차로 (Crossroads)_여자친구 (GFRIEND) 결측값 발생
# 2020-02-08 08:00:00 나의 모든 날_김세정 결측값 발생
# 2020-02-08 08:00:00 새 사랑_송하예 결측값 발생
# 2020-02-08 08:00:00 IDOL_방탄소년단 결측값 발생
# 2020-02-08 08:00:00 2002_Anne-Marie 결측값 발생
# 2020-02-08 08:00:00 Nerdy Love (Feat. 백예린)_pH-1 결측값 발생
# 2020-02-08 08:00:00 소우주 (Mikrokosmos)_방탄소년단 결측값 발생
# 2020-02-08 08:00:00 포장마차_황인욱 결측값 발생
# 2020-02-08 08:00:00 헤어진 우리가 지켜야 할 것들_김나영, 양다일, 김나영 & 양다일 결측값 발생
# 2020-02-08 08:00:00 Birthday_Anne-Marie 결측값 발생
# 2020-02-08 08:00:00 나의 오랜 연인에게_다비치 결측값 발생
# 2020-02-08 08:00:00 사랑이 식었다고 말해도 돼_먼데이 키즈 (Monday Kiz) 결측값 발생
# 2020-02-08 08:00:00 있어줘요_장덕철 결측값 발생
# 2020-02-08 08:00:00 니 소식_송하예 결측값 발생
# 2020-02-08 08:00:00 시든 꽃에 물을 주듯_HYNN (박혜원) 결측값 발생
# 2020-02-08 08:00:00 사랑에 연습이 있었다면 (Prod. by 2soo)_임재현 결측값 발생
# 2020-02-08 08:00:00 Make It Right_방탄소년단 결측값 발생
# 2020-02-08 08:00:00 bad guy_Billie Eilish 결측값 발생
# 2020-02-08 08:00:00 Dionysus_방탄소년단 결측값 발생
# 2020-02-08 08:00:00 우는 법을 잊어버렸나요_이해리 (다비치) 결측값 발생
# 2020-02-08 08:00:00 기억해줘요 내 모든 날과 그때를_거미 (Gummy) 결측값 발생
# 2020-02-08 08:00:00 인기 (Feat. 송가인 & 챈슬러)_MC몽 결측값 발생
# 2020-02-08 08:00:00 너를 만나_폴킴 결측값 발생
# 2020-02-08 08:00:00 불티 (Spark)_태연 (TAEYEON) 결측값 발생
# 2020-02-08 08:00:00 Memories_Maroon 5 결측값 발생
# 2020-02-08 08:00:00 Senorita_Shawn Mendes, Camila Cabello & Shawn Mendes, Camila Cabello 결측값 발생
# 2020-02-08 08:00:00 이별주_황인욱 결측값 발생
# 2020-02-08 08:00:00 이 번호로 전화해줘_바이브 결측값 발생
# 2020-02-08 08:00:00 Comethru_Jeremy Zucker 결측값 발생
# 2020-02-08 08:00:00 Paris in the Rain_Lauv 결측값 발생
# 2020-02-08 08:00:00 Flower_윤미래 결측값 발생
# 2020-02-08 08:00:00 내게 들려주고 싶은 말 (Dear Me)_태연 (TAEYEON) 결측값 발생
# 2020-02-08 08:00:00 워커홀릭_볼빨간사춘기 결측값 발생
# 2020-02-08 08:00:00 Into the Unknown_Idina Menzel, AURORA, Idina Menzel & AURORA 결측값 발생
# 2020-02-08 08:00:00 Obsession_EXO 결측값 발생
# 2020-02-08 08:00:00 술이 문제야_장혜진, 윤민수(바이브), 장혜진 & 윤민수(바이브) 결측값 발생
# 2020-02-08 08:00:00 BAND_창모 (CHANGMO), 김효은, Hash Swan, ASH ISLAND, 창모 & Hash Swan & ASH ISLAND & 김효은 결측값 발생
# 2020-02-08 08:00:00 십이월 이십오일의 고백_정승환 결측값 발생
# 2020-02-08 08:00:00 헤어지자 (Prod. by 정키 (Jung Key))_휘인 (Whee In) 결측값 발생
# 2020-02-08 08:00:00 우리 왜 헤어져야 해_신예영 결측값 발생
# 2020-02-08 08:00:00 잘 살고 있다_V.O.S 결측값 발생
# 2020-02-08 08:00:00 그대라는 시_태연 (TAEYEON) 결측값 발생
# 2020-02-08 08:00:00 가을밤 떠난 너_케이시 (Kassy) 결측값 발생
# 2020-02-08 08:00:00 그때가 좋았어_케이시 (Kassy) 결측값 발생
# 2020-02-08 08:00:00 차가워진 이 바람엔 우리가 써있어 (Bad Love)_HYNN (박혜원) 결측값 발생
# 2020-02-08 08:00:00 시간의 바깥_아이유 (IU) 결측값 발생
# 2020-02-08 08:00:00 사계 (Four Seasons)_태연 (TAEYEON) 결측값 발생
# 2020-02-08 08:00:00 그때의 우리_펀치 (Punch) 결측값 발생
# 2020-02-08 08:00:00 내 생에 아름다운_케이윌 (K.Will) 결측값 발생
# 2020-02-08 08:00:00 허전해_폴킴 결측값 발생
# 2020-02-08 08:00:00 주저하는 연인들을 위해_잔나비 결측값 발생
# 2020-02-08 08:00:00 벗_닐로 (Nilo) 결측값 발생
# 2020-02-08 08:00:00 가라고 (Gotta Go)_선미 결측값 발생
# 2020-02-08 08:00:00 꿈속에 너 (Feat. 전상근)_에이치코드 (H:CODE) 결측값 발생
# 2020-02-08 08:00:00 On My Way_Sabrina Carpenter, Farruko, Alan Walker, Alan Walker & Sabrina Carpenter & Farruko 결측값 발생
# 2020-02-08 08:00:00 All Falls Down (Feat. Juliander)_Digital Farm Animals, Alan Walker, Noah Cyrus, Alan Walker & Noah Cyrus & Digital Farm Animals 결측값 발생
# 2020-02-08 08:00:00 너에게 못했던 내 마지막 말은_다비치 결측값 발생
# 2020-02-08 08:00:00 나의 어깨에 기대어요_10CM 결측값 발생
# 2020-02-08 08:00:00 노래방에서_장범준 결측값 발생
# 2020-02-08 08:00:00 Way Back Home_숀 (SHAUN) 결측값 발생
# 2020-02-08 08:00:00 안녕하세요_김재환 결측값 발생
# 2020-02-08 08:00:00 Feel Special_TWICE (트와이스) 결측값 발생
# 2020-02-08 08:00:00 하루에도 열두 번_윤건 결측값 발생
# 2020-02-08 08:00:00 뛰어들게 (Dive)_iKON 결측값 발생
# 2020-02-08 08:00:00 사계 (하루살이)_엠씨더맥스 (M.C the MAX) 결측값 발생
# 2020-02-08 08:00:00 넘쳐흘러_엠씨더맥스 (M.C the MAX) 결측값 발생
# 2020-02-08 08:00:00 헤어져줘서 고마워_벤 결측값 발생
# 2020-02-08 08:00:00 노을_다비치 결측값 발생
# 2020-03-01 00:00:00 시작
# --------------------------------------------------
# 2020-03-26 02:00:00에 해당하는 페이지에는 음원 정보가 없음
# --------------------------------------------------
# --------------------------------------------------
# 2020-03-26 03:00:00에 해당하는 페이지에는 음원 정보가 없음
# --------------------------------------------------
# --------------------------------------------------
# 2020-03-26 04:00:00에 해당하는 페이지에는 음원 정보가 없음
# --------------------------------------------------
# --------------------------------------------------
# 2020-03-26 05:00:00에 해당하는 페이지에는 음원 정보가 없음
# --------------------------------------------------
# 2020-04-01 00:00:00 시작
# 2020-05-01 00:00:00 시작
# 2020-06-01 00:00:00 시작
# 2020-07-01 00:00:00 시작
# --------------------------------------------------
# 2020-07-26 04:00:00에 해당하는 페이지에는 음원 정보가 없음
# --------------------------------------------------
# --------------------------------------------------
# 2020-07-26 05:00:00에 해당하는 페이지에는 음원 정보가 없음
# --------------------------------------------------
# 2020-08-01 00:00:00 시작
# 2020-08-27 19:00:00 듣고 싶던 말_허각 결측값 발생
# 2020-08-27 19:00:00 비행_E SENS 결측값 발생
# 2020-09-01 00:00:00 시작
# 2020-09-27 09:00:00 사랑은 지날수록 더욱 선명하게 남아_전상근 결측값 발생
# 2020-09-27 09:00:00 Don't Start Now_Dua Lipa 결측값 발생
# 2020-09-27 09:00:00 안녕_폴킴 결측값 발생
# 2020-09-27 09:00:00 시차_방탄소년단 결측값 발생
# 2020-09-27 10:00:00 사랑은 지날수록 더욱 선명하게 남아_전상근 결측값 발생
# 2020-09-27 10:00:00 Don't Start Now_Dua Lipa 결측값 발생
# 2020-09-27 10:00:00 안녕_폴킴 결측값 발생
# 2020-09-27 10:00:00 시차_방탄소년단 결측값 발생
# 2020-10-01 00:00:00 시작
# --------------------------------------------------
# 2020-10-22 03:00:00에 해당하는 페이지에는 음원 정보가 없음
# --------------------------------------------------
# --------------------------------------------------
# 2020-10-22 04:00:00에 해당하는 페이지에는 음원 정보가 없음
# --------------------------------------------------
# --------------------------------------------------
# 2020-10-22 05:00:00에 해당하는 페이지에는 음원 정보가 없음
# --------------------------------------------------
# 2020-11-01 00:00:00 시작
# --------------------------------------------------
# 2020-11-08 03:00:00에 해당하는 페이지에는 음원 정보가 없음
# --------------------------------------------------
# --------------------------------------------------
# 2020-11-08 04:00:00에 해당하는 페이지에는 음원 정보가 없음
# --------------------------------------------------
# --------------------------------------------------
# 2020-11-08 05:00:00에 해당하는 페이지에는 음원 정보가 없음
# --------------------------------------------------
# 2020-11-20 15:00:00 내 방을 여행하는 법_방탄소년단 결측값 발생
# 2020-11-20 15:00:00 Blue & Grey_방탄소년단 결측값 발생
# 2020-11-20 15:00:00 잠시_방탄소년단 결측값 발생
# 2020-11-20 15:00:00 병_방탄소년단 결측값 발생
# 2020-11-20 15:00:00 Stay_방탄소년단 결측값 발생
# 2020-11-20 15:00:00 Skit_방탄소년단 결측값 발생
# 2020-11-20 15:00:00 Dynamite_방탄소년단 결측값 발생
# 2020-12-01 00:00:00 시작
# 2021-01-01 00:00:00 시작
# 2021-02-01 00:00:00 시작
# 2021-03-01 00:00:00 시작
# 2021-04-01 00:00:00 시작
# 2021-05-01 00:00:00 시작
# 2021-06-01 00:00:00 시작
# 2021-07-01 00:00:00 시작
# 2021-08-01 00:00:00 시작
# --------------------------------------------------
# 2021-08-28 02:00:00에 해당하는 페이지에는 음원 정보가 없음
# --------------------------------------------------
# --------------------------------------------------
# 2021-08-28 03:00:00에 해당하는 페이지에는 음원 정보가 없음
# --------------------------------------------------
# --------------------------------------------------
# 2021-08-28 04:00:00에 해당하는 페이지에는 음원 정보가 없음
# --------------------------------------------------
# --------------------------------------------------
# 2021-08-28 05:00:00에 해당하는 페이지에는 음원 정보가 없음
# --------------------------------------------------
# --------------------------------------------------
# 2021-08-28 06:00:00에 해당하는 페이지에는 음원 정보가 없음
# --------------------------------------------------
# 2021-08-31 19:00:00 시간을 거슬러 (낮에 뜨는 달 X 케이윌)_케이윌 (K.Will) 결측값 발생
# 2021-09-01 00:00:00 시작
# 2021-09-01 19:00:00 별이 빛나는 밤에_규현 (KYUHYUN) 결측값 발생
# 2021-09-01 19:00:00 오늘은 가지마 (2021)_환희 결측값 발생
# 2021-09-03 19:00:00 수취인불명_이해리 (다비치), 매드 클라운 (Mad Clown), 매드 클라운 (Mad Clown) & 이해리 (다비치) 결측값 발생
# 2021-09-06 19:00:00 색안경 (STEREOTYPE)_STAYC (스테이씨) 결측값 발생
# 2021-09-06 19:00:00 끝까지 안아 줄게_Young K (DAY6) 결측값 발생
# 2021-09-07 19:00:00 사랑합니다_하은 (포맨) 결측값 발생
# 2021-09-07 19:00:00 아무것도 하기 싫으면 어떡해_백아연 결측값 발생
# 2021-09-09 19:00:00 빨간 립스틱 (Feat. 윤미래)_이하이 결측값 발생
# 2021-09-09 19:00:00 PING PONG_현아, 던 (DAWN), 현아 & 던 (DAWN) 결측값 발생
# 2021-09-10 19:00:00 그럴때마다_백예린 (Yerin Baek) 결측값 발생
# 2021-09-10 19:00:00 산책_백예린 (Yerin Baek) 결측값 발생
# 2021-09-10 19:00:00 왜? 날_백예린 (Yerin Baek) 결측값 발생
# 2021-09-10 19:00:00 Antifreeze_백예린 (Yerin Baek) 결측값 발생
# 2021-09-10 19:00:00 돌아가자_백예린 (Yerin Baek) 결측값 발생
# 2021-09-13 19:00:00 부디_지아 (Zia) 결측값 발생
# 2021-09-14 19:00:00 가을 타나 봐_이무진 결측값 발생
# 2021-10-01 00:00:00 시작
# 2021-11-01 00:00:00 시작
# 2021-12-01 00:00:00 시작
# 2022-01-01 00:00:00 시작
# 2022-02-01 00:00:00 시작
# 2022-03-01 00:00:00 시작
# 2022-04-01 00:00:00 시작
# --------------------------------------------------
# 2022-04-06 03:00:00에 해당하는 페이지에는 음원 정보가 없음
# --------------------------------------------------
# --------------------------------------------------
# 2022-04-06 04:00:00에 해당하는 페이지에는 음원 정보가 없음
# --------------------------------------------------
# 2022-05-01 00:00:00 시작
# 2022-06-01 00:00:00 시작
# 2022-07-01 00:00:00 시작
# --------------------------------------------------
# 2022-07-08 02:00:00에 해당하는 페이지에는 음원 정보가 없음
# --------------------------------------------------
# --------------------------------------------------
# 2022-07-08 03:00:00에 해당하는 페이지에는 음원 정보가 없음
# --------------------------------------------------
# --------------------------------------------------
# 2022-07-08 04:00:00에 해당하는 페이지에는 음원 정보가 없음
# --------------------------------------------------
# --------------------------------------------------
# 2022-07-08 05:00:00에 해당하는 페이지에는 음원 정보가 없음
# --------------------------------------------------
# --------------------------------------------------
# 2022-07-08 06:00:00에 해당하는 페이지에는 음원 정보가 없음
# --------------------------------------------------
# 2022-07-08 07:00:00 사랑은 늘 도망가_임영웅 결측값 발생
# 2022-07-08 07:00:00 우리들의 블루스_임영웅 결측값 발생
# 2022-07-08 07:00:00 다시 만날 수 있을까_임영웅 결측값 발생
# 2022-07-08 07:00:00 무지개_임영웅 결측값 발생
# 2022-07-08 07:00:00 아버지_임영웅 결측값 발생
# 2022-07-08 07:00:00 이제 나만 믿어요_임영웅 결측값 발생
# 2022-07-08 07:00:00 A bientot_임영웅 결측값 발생
# 2022-07-08 07:00:00 손이 참 곱던 그대_임영웅 결측값 발생
# 2022-07-08 07:00:00 사랑역_임영웅 결측값 발생
# 2022-07-08 07:00:00 보금자리_임영웅 결측값 발생
# 2022-07-08 07:00:00 사랑해 진짜_임영웅 결측값 발생
# 2022-07-08 07:00:00 연애편지_임영웅 결측값 발생
# 2022-07-08 07:00:00 인생찬가_임영웅 결측값 발생
# 2022-07-08 07:00:00 사랑해요 그대를_임영웅 결측값 발생
# 2022-07-08 07:00:00 LOVE DIVE_IVE (아이브) 결측값 발생
# 2022-07-08 07:00:00 That That (Prod. & Feat. SUGA of BTS)_싸이 (Psy) 결측값 발생
# 2022-07-08 07:00:00 TOMBOY_(여자)아이들 결측값 발생
# 2022-07-08 07:00:00 POP!_나연 (TWICE) 결측값 발생
# 2022-07-08 07:00:00 사랑인가 봐_멜로망스 (MeloMance) 결측값 발생
# 2022-07-08 07:00:00 나의 X에게_경서 결측값 발생
# 2022-07-08 07:00:00 정이라고 하자 (Feat. 10CM)_BIG Naughty (서동현) 결측값 발생
# 2022-07-08 07:00:00 Yet To Come_방탄소년단 결측값 발생
# 2022-07-08 07:00:00 봄여름가을겨울 (Still Life)_BIGBANG (빅뱅) 결측값 발생
# 2022-07-08 07:00:00 만개 (Prod. 신지후)_김호중 결측값 발생
# 2022-07-08 07:00:00 내가 아니라도_주호 결측값 발생
# 2022-07-08 07:00:00 LOVE me_BE'O (비오) 결측값 발생
# 2022-07-08 07:00:00 취중고백_김민석 (멜로망스) 결측값 발생
# 2022-07-08 07:00:00 빛이 나는 사람_김호중 결측값 발생
# 2022-07-08 07:00:00 나보다 더 사랑해요_김호중 결측값 발생
# 2022-07-08 07:00:00 살았소_김호중 결측값 발생
# 2022-07-08 07:00:00 우산이 없어요_김호중 결측값 발생
# 2022-07-08 07:00:00 퇴근길_김호중 결측값 발생
# 2022-07-08 07:00:00 아무도 잠들지 마라 (Nessun Dorma)_김호중 결측값 발생
# 2022-07-08 07:00:00 나만의 길 (My Way)_김호중 결측값 발생
# 2022-07-08 07:00:00 Left and Right (Feat. Jung Kook of BTS)_방탄소년단, Charlie Puth, 정국, Charlie Puth & 정국 & 방탄소년단 결측값 발생
# 2022-07-08 07:00:00 I LOVE U_WINNER 결측값 발생
# 2022-07-08 07:00:00 희망가 (Prod. by 이지수)_김호중 결측값 발생
# 2022-07-08 07:00:00 Dynamite_방탄소년단 결측값 발생
# 2022-07-08 07:00:00 백화 (白花) (Narration. 손숙)_김호중 결측값 발생
# 2022-07-08 07:00:00 위대한 사랑 (Un Amore Cosi Grande)_김호중 결측값 발생
# 2022-07-08 07:00:00 홀로아리랑 (Prod. by 박경훈)_김호중 결측값 발생
# 2022-07-08 07:00:00 다정히 내 이름을 부르면_전건호, 경서예지, 경서예지 & 전건호 결측값 발생
# 2022-07-08 07:00:00 없었던 일로_헤이즈 (Heize) 결측값 발생
# 2022-07-08 07:00:00 여자의 마음 (La Donna E Mobile)_김호중 결측값 발생
# 2022-07-08 07:00:00 Butter_방탄소년단 결측값 발생
# 2022-07-08 07:00:00 신호등_이무진 결측값 발생
# 2022-07-08 07:00:00 Permission to Dance_방탄소년단 결측값 발생
# 2022-07-08 07:00:00 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)_방탄소년단 결측값 발생
# 2022-07-08 07:00:00 MY BAG_(여자)아이들 결측값 발생
# 2022-07-08 07:00:00 FEARLESS_LE SSERAFIM (르세라핌) 결측값 발생
# 2022-07-08 07:00:00 Feel My Rhythm_Red Velvet (레드벨벳) 결측값 발생
# 2022-07-08 07:00:00 아무래도 난_주시크 (Joosiq) 결측값 발생
# 2022-07-08 07:00:00 My Universe_Coldplay, 방탄소년단, Coldplay & 방탄소년단 결측값 발생
# 2022-07-08 07:00:00 봄날_방탄소년단 결측값 발생
# 2022-07-08 07:00:00 해요 (2022)_#안녕 결측값 발생
# 2022-07-08 07:00:00 Stay_Justin Bieber, The Kid LAROI, The Kid LAROI & Justin Bieber 결측값 발생
# 2022-07-08 07:00:00 듣고 싶을까_MSG워너비 (M.O.M) 결측값 발생
# 2022-07-08 07:00:00 With you_지민, 하성운, 지민 & 하성운 결측값 발생
# 2022-07-08 07:00:00 That's Hilarious_Charlie Puth 결측값 발생
# 2022-07-08 07:00:00 그라데이션_10CM 결측값 발생
# 2022-07-08 07:00:00 팡파레_다비치 결측값 발생
# 2022-07-08 07:00:00 Born Singer_방탄소년단 결측값 발생
# 2022-07-08 07:00:00 GANADARA (Feat. 아이유)_박재범 결측값 발생
# 2022-07-08 07:00:00 너의 모든 순간_성시경 결측값 발생
# 2022-07-08 07:00:00 고백하는 취한밤에 (Prod. by 2soo)_임재현 결측값 발생
# 2022-07-08 07:00:00 INVU_태연 (TAEYEON) 결측값 발생
# 2022-07-08 07:00:00 ELEVEN_IVE (아이브) 결측값 발생
# 2022-07-08 07:00:00 달려라 방탄_방탄소년단 결측값 발생
# 2022-07-08 07:00:00 MORE_j-hope 결측값 발생
# 2022-07-08 07:00:00 OHAYO MY NIGHT_디핵 (D-Hack), PATEKO (파테코), 디핵 (D-Hack) & PATEKO 결측값 발생
# 2022-07-08 07:00:00 내 손을 잡아_아이유 (IU) 결측값 발생
# 2022-07-08 07:00:00 For Youth_방탄소년단 결측값 발생
# 2022-07-08 07:00:00 HOT_세븐틴 (SEVENTEEN) 결측값 발생
# 2022-07-08 07:00:00 너를 생각해_주시크 (Joosiq) 결측값 발생
# 2022-07-08 07:00:00 Weekend_태연 (TAEYEON) 결측값 발생
# 2022-07-08 07:00:00 늦은 밤 헤어지긴 너무 아쉬워_케이시 (Kassy) 결측값 발생
# 2022-07-08 07:00:00 바라만 본다_MSG워너비 (M.O.M) 결측값 발생
# 2022-07-08 07:00:00 Next Level_aespa 결측값 발생
# 2022-07-08 07:00:00 abcdefu_GAYLE 결측값 발생
# 2022-07-08 07:00:00 그 하루 (Feat. 반하나)_주호 결측값 발생
# 2022-07-08 07:00:00 회전목마 (Feat. Zion.T & 원슈타인) (Prod. by Slom)_sokodomo 결측값 발생
# 2022-07-08 07:00:00 모든 날, 모든 순간 (Every day, Every Moment)_폴킴 결측값 발생
# 2022-07-08 07:00:00 리무진 (Feat. MINO) (Prod. by GRAY)_BE'O (비오) 결측값 발생
# 2022-07-08 07:00:00 호랑수월가_탑현 결측값 발생
# 2022-07-08 07:00:00 strawberry moon_아이유 (IU) 결측값 발생
# 2022-07-08 07:00:00 늦은 밤 너의 집 앞 골목길에서_노을 결측값 발생
# 2022-07-08 07:00:00 Bad Habits_Ed Sheeran 결측값 발생
# 2022-07-08 07:00:00 언제나 사랑해_케이시 (Kassy) 결측값 발생
# 2022-07-08 07:00:00 ZOOM_제시 결측값 발생
# 2022-07-08 07:00:00 Love story_볼빨간사춘기 결측값 발생
# 2022-07-08 07:00:00 찰나가 영원이 될 때 (The Eternal Moment)_마크툽 (Maktub) 결측값 발생
# 2022-07-08 07:00:00 밤하늘의 별을 (2020)_경서 결측값 발생
# 2022-07-08 07:00:00 Every Second_Mina Okabe 결측값 발생
# 2022-07-08 07:00:00 추억은 만남보다 이별에 남아_정동하 결측값 발생
# 2022-07-08 07:00:00 밤편지_아이유 (IU) 결측값 발생
# 2022-07-08 07:00:00 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)_마크툽 (Maktub) 결측값 발생
# 2022-07-08 07:00:00 미친 것처럼_V.O.S 결측값 발생
# 2022-07-08 07:00:00 마음을 드려요_아이유 (IU) 결측값 발생
# 2022-07-08 07:00:00 Stronger (What Doesn't Kill You)_Kelly Clarkson 결측값 발생
# 2022-07-08 07:00:00 Loving You Girl (Feat. Hkeem)_Peder Elias 결측값 발생
# 2022-08-01 00:00:00 시작
# 2022-08-30 10:00:00 After LIKE_IVE (아이브) 결측값 발생
# 2022-08-30 10:00:00 Pink Venom_BLACKPINK 결측값 발생
# 2022-08-30 10:00:00 Attention_NewJeans 결측값 발생
# 2022-08-30 10:00:00 Hype boy_NewJeans 결측값 발생
# 2022-08-30 10:00:00 FOREVER 1_소녀시대 (GIRLS' GENERATION) 결측값 발생
# 2022-08-30 10:00:00 그때 그 순간 그대로 (그그그)_WSG워너비 (가야G) 결측값 발생
# 2022-08-30 10:00:00 LOVE DIVE_IVE (아이브) 결측값 발생
# 2022-08-30 10:00:00 보고싶었어_WSG워너비 (4FIRE) 결측값 발생
# 2022-08-30 10:00:00 SNEAKERS_ITZY (있지) 결측값 발생
# 2022-08-30 10:00:00 Cookie_NewJeans 결측값 발생
# 2022-08-30 10:00:00 사랑은 늘 도망가_임영웅 결측값 발생
# 2022-08-30 10:00:00 TOMBOY_(여자)아이들 결측값 발생
# 2022-08-30 10:00:00 우리들의 블루스_임영웅 결측값 발생
# 2022-08-30 10:00:00 그라데이션_10CM 결측값 발생
# 2022-08-30 10:00:00 나의 X에게_경서 결측값 발생
# 2022-08-30 10:00:00 다시 만날 수 있을까_임영웅 결측값 발생
# 2022-08-30 10:00:00 사랑인가 봐_멜로망스 (MeloMance) 결측값 발생
# 2022-08-30 10:00:00 That That (Prod. & Feat. SUGA of BTS)_싸이 (Psy) 결측값 발생
# 2022-08-30 10:00:00 이제 나만 믿어요_임영웅 결측값 발생
# 2022-08-30 10:00:00 도깨비불 (Illusion)_aespa 결측값 발생
# 2022-08-30 10:00:00 POP!_나연 (TWICE) 결측값 발생
# 2022-08-30 10:00:00 무지개_임영웅 결측값 발생
# 2022-08-30 10:00:00 정이라고 하자 (Feat. 10CM)_BIG Naughty (서동현) 결측값 발생
# 2022-08-30 10:00:00 아버지_임영웅 결측값 발생
# 2022-08-30 10:00:00 Love story_볼빨간사춘기 결측값 발생
# 2022-08-30 10:00:00 A bientot_임영웅 결측값 발생
# 2022-08-30 10:00:00 잠수이별 (Prod. by 코드 쿤스트)_우원재, meenoi (미노이), 우원재 (Woo) & meenoi (미노이) 결측값 발생
# 2022-08-30 10:00:00 손이 참 곱던 그대_임영웅 결측값 발생
# 2022-08-30 10:00:00 That's Hilarious_Charlie Puth 결측값 발생
# 2022-08-30 10:00:00 내가 아니라도_주호 결측값 발생
# 2022-08-30 10:00:00 사랑해 진짜_임영웅 결측값 발생
# 2022-08-30 10:00:00 ELEVEN_IVE (아이브) 결측값 발생
# 2022-08-30 10:00:00 사랑역_임영웅 결측값 발생
# 2022-08-30 10:00:00 LOVE me_BE'O (비오) 결측값 발생
# 2022-08-30 10:00:00 연애편지_임영웅 결측값 발생
# 2022-08-30 10:00:00 사랑해요 그대를_임영웅 결측값 발생
# 2022-08-30 10:00:00 보금자리_임영웅 결측값 발생
# 2022-08-30 10:00:00 바보에게 바보가 (웹툰 '연애의 발견' X 이석훈)_이석훈 결측값 발생
# 2022-08-30 10:00:00 해요 (2022)_#안녕 결측값 발생
# 2022-08-30 10:00:00 인생찬가_임영웅 결측값 발생
# 2022-08-30 10:00:00 봄여름가을겨울 (Still Life)_BIGBANG (빅뱅) 결측값 발생
# 2022-08-30 10:00:00 내 기쁨은 너가 벤틀리를 끄는 거야_김승민 결측값 발생
# 2022-08-30 10:00:00 다정히 내 이름을 부르면_전건호, 경서예지, 경서예지 & 전건호 결측값 발생
# 2022-08-30 10:00:00 취중고백_김민석 (멜로망스) 결측값 발생
# 2022-08-30 10:00:00 FEARLESS_LE SSERAFIM (르세라핌) 결측값 발생
# 2022-08-30 10:00:00 Girls_aespa 결측값 발생
# 2022-08-30 10:00:00 Talk that Talk_TWICE (트와이스) 결측값 발생
# 2022-08-30 10:00:00 너의 모든 순간_성시경 결측값 발생
# 2022-08-30 10:00:00 통화연결음_MJ (써니사이드), 보라미유, 보라미유 & MJ (써니사이드) 결측값 발생
# 2022-08-30 10:00:00 신호등_이무진 결측값 발생
# 2022-08-30 10:00:00 Stay_Justin Bieber, The Kid LAROI, The Kid LAROI & Justin Bieber 결측값 발생
# 2022-08-30 10:00:00 열이올라요 (Heart Burn)_선미 결측값 발생
# 2022-08-30 10:00:00 MY BAG_(여자)아이들 결측값 발생
# 2022-08-30 10:00:00 새벽에 걸려온 너의 전화는_한동근 결측값 발생
# 2022-08-30 10:00:00 사랑한다고 말해줘_탑현 결측값 발생
# 2022-08-30 10:00:00 팡파레_다비치 결측값 발생
# 2022-08-30 10:00:00 듣고 싶을까_MSG워너비 (M.O.M) 결측값 발생
# 2022-08-30 10:00:00 Dynamite_방탄소년단 결측값 발생
# 2022-08-30 10:00:00 Clink Clink (클링 클링)_WSG워너비 (오아시소) 결측값 발생
# 2022-08-30 10:00:00 Feel My Rhythm_Red Velvet (레드벨벳) 결측값 발생
# 2022-08-30 10:00:00 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지_AKMU (악뮤) 결측값 발생
# 2022-08-30 10:00:00 비가 오는 날엔 (2021)_헤이즈 (Heize) 결측값 발생
# 2022-08-30 10:00:00 GANADARA (Feat. 아이유)_박재범 결측값 발생
# 2022-08-30 10:00:00 빛이 나는 사람_김호중 결측값 발생
# 2022-08-30 10:00:00 Bad Habits_Ed Sheeran 결측값 발생
# 2022-08-30 10:00:00 밤하늘의 별을 (2020)_경서 결측값 발생
# 2022-08-30 10:00:00 Left and Right (Feat. Jung Kook of BTS)_방탄소년단, Charlie Puth, 정국, Charlie Puth & 정국 & 방탄소년단 결측값 발생
# 2022-08-30 10:00:00 주마등_김호중 결측값 발생
# 2022-08-30 10:00:00 INVU_태연 (TAEYEON) 결측값 발생
# 2022-08-30 10:00:00 회전목마 (Feat. Zion.T & 원슈타인) (Prod. by Slom)_sokodomo 결측값 발생
# 2022-08-30 10:00:00 바라만 본다_MSG워너비 (M.O.M) 결측값 발생
# 2022-08-30 10:00:00 스티커 사진_21학번 결측값 발생
# 2022-08-30 10:00:00 아무래도 난_주시크 (Joosiq) 결측값 발생
# 2022-08-30 10:00:00 모든 날, 모든 순간 (Every day, Every Moment)_폴킴 결측값 발생
# 2022-08-30 10:00:00 OHAYO MY NIGHT_디핵 (D-Hack), PATEKO (파테코), 디핵 (D-Hack) & PATEKO 결측값 발생
# 2022-08-30 10:00:00 Next Level_aespa 결측값 발생
# 2022-08-30 10:00:00 약속 (約束)_김호중 결측값 발생
# 2022-08-30 10:00:00 너를 생각해_주시크 (Joosiq) 결측값 발생
# 2022-08-30 10:00:00 I LOVE U_WINNER 결측값 발생
# 2022-08-30 10:00:00 Weekend_태연 (TAEYEON) 결측값 발생
# 2022-08-30 10:00:00 Loving You Girl (Feat. Hkeem)_Peder Elias 결측값 발생
# 2022-08-30 10:00:00 Yet To Come_방탄소년단 결측값 발생
# 2022-08-30 10:00:00 Oye Como Va_김호중 결측값 발생
# 2022-08-30 10:00:00 친구_김호중 결측값 발생
# 2022-08-30 10:00:00 늦은 밤 헤어지긴 너무 아쉬워_케이시 (Kassy) 결측값 발생
# 2022-08-30 10:00:00 2002_Anne-Marie 결측값 발생
# 2022-08-30 10:00:00 언제나 사랑해_케이시 (Kassy) 결측값 발생
# 2022-08-30 10:00:00 strawberry moon_아이유 (IU) 결측값 발생
# 2022-08-30 10:00:00 Stronger (What Doesn't Kill You)_Kelly Clarkson 결측값 발생
# 2022-08-30 10:00:00 Adoro_김호중 결측값 발생
# 2022-08-30 10:00:00 나비 (Outro)_김호중 결측값 발생
# 2022-08-30 10:00:00 Butter_방탄소년단 결측값 발생
# 2022-08-30 10:00:00 가을꽃_김호중 결측값 발생
# 2022-08-30 10:00:00 My Universe_Coldplay, 방탄소년단, Coldplay & 방탄소년단 결측값 발생
# 2022-08-30 10:00:00 Tiritomba_김호중 결측값 발생
# 2022-08-30 10:00:00 Love in Portofino_김호중 결측값 발생
# 2022-08-30 10:00:00 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)_마크툽 (Maktub) 결측값 발생
# 2022-08-30 10:00:00 그리움의 계절_김호중 결측값 발생
# 2022-08-30 10:00:00 리무진 (Feat. MINO) (Prod. by GRAY)_BE'O (비오) 결측값 발생
# 2022-08-30 10:00:00 노래해요 (Duet With 최백호)_김호중 결측값 발생
# 2022-09-01 00:00:00 시작
# --------------------------------------------------
# 2022-09-02 06:00:00에 해당하는 페이지에는 음원 정보가 없음
# --------------------------------------------------
# 2022-10-01 00:00:00 시작
# 2022-11-01 00:00:00 시작
# 2022-12-01 00:00:00 시작
# 2023-01-01 00:00:00 시작
# 2023-02-01 00:00:00 시작
# 2023-03-01 00:00:00 시작
# --------------------------------------------------
# 2023-03-22 03:00:00에 해당하는 페이지에는 음원 정보가 없음
# --------------------------------------------------
# 2023-04-01 00:00:00 시작
# 2023-05-01 00:00:00 시작

# %%
with open(raw_data_path + 'raw_data.json', 'w', encoding='utf-8') as f:
    json.dump(data, f, indent='\t', ensure_ascii=False)
